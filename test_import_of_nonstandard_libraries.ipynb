-- %%
{-# LANGUAGE GADTs #-}

-- %%
import Yesod
import qualified Foundation as F
import Yesod.Core

-- %%
import Data.Composition -- external module, must be enlisted in stack.yaml of IHaskell

-- %%
import Control.Monad.Trans.Resource.Internal
:t liftResourceT
-- Out:
-- liftResourceT :: forall (m :: * -> *) a. MonadResource m => ResourceT IO a -> m a

-- %%
import Language.C.Clang
import Language.C.Clang.TranslationUnit
:t parseTranslationUnit
-- Out:
-- parseTranslationUnit :: ClangIndex -> FilePath -> [String] -> IO TranslationUnit

-- %%
import Haxl.Core
import qualified Data.Typeable
import qualified Data.Text
:t dataFetch
-- Out:
-- dataFetch :: forall u a (r :: * -> *). (Show (r a), Show a, Typeable a, Hashable (r a), Eq (r a), DataSource u r) => r a -> GenHaxl u a

-- %%
import Data.Enumerator
-- Out:
-- <interactive>:1:1: error:
--     Failed to load interface for ‘Data.Enumerator’
--     Use -v to see a list of the files searched for.

-- %%
:t foldl
:t print
cmd3 = print .:. foldl
:t cmd3
cmd3 (+) 0 [2,3,5,7]
-- Out:
-- foldl :: forall (t :: * -> *) a b. Foldable t => (b -> a -> b) -> b -> t a -> b
-- print :: forall a. Show a => a -> IO ()
-- cmd3 :: forall (t :: * -> *) a a1. (Show a1, Foldable t) => (a1 -> a -> a1) -> a1 -> t a -> IO ()
-- 17

-- %% [markdown]
-- The following does **not compose** correctly because g function (in f.g composition) has **arity > 1**

-- %%
{-# LANGUAGE FlexibleContexts ,AllowAmbiguousTypes #-}
cmd3' =  print . foldl
:t cmd3'
cmd3' (+) 0 [2,3,5,7] 
--cmd3'' =  print $ foldl  -- this even fails to compose
-- Out:
-- cmd3' :: forall (t :: * -> *) a b. (Show (b -> t a -> b), Foldable t) => (b -> a -> b) -> IO ()
-- <interactive>:1:1: error:
--     • Couldn't match expected type ‘Integer -> [Integer] -> t’ with actual type ‘IO ()’
--     • The function ‘cmd3'’ is applied to three arguments,
--       but its type ‘(b0 -> b0 -> b0) -> IO ()’ has only one
--       In the expression: cmd3' (+) 0 [2, 3, 5, 7]
--       In an equation for ‘it’: it = cmd3' (+) 0 [2, 3, 5, ....]
--     • Relevant bindings include it :: t (bound at <interactive>:1:1)

-- %%
--import Data.Text hiding (foldl, (+))
import qualified Data.Text as DT

import Data.Aeson
toJSON  (12 ::Integer)
toJSON  "Ala"

import Data.Composition
fd = print .:. foldl  
:t fd
fd (+) 0 [3,5,7,9]
-- Out:
-- Number 12.0
-- String "Ala"
-- fd :: forall (t :: * -> *) a a1. (Show a1, Foldable t) => (a1 -> a -> a1) -> a1 -> t a -> IO ()
-- 24

-- %%
data App = App
    
--mkYesodData "App" $(parseRoutesFile "routes")
instance Yesod App
-- Out:
-- <interactive>:2:10: error:
--     • No instance for (RenderRoute App) arising from the superclasses of an instance declaration
--     • In the instance declaration for ‘Yesod App’
